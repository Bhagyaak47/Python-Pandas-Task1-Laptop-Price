# %%
import pandas as pd



a=pd.read_csv("laptop_price .csv")

df=pd.DataFrame(a)
df
# Out:
#      laptop_ID Company          Product   TypeName  Inches  \
# 0            1   Apple      MacBook Pro  Ultrabook    13.3
# 1            2   Apple      Macbook Air  Ultrabook    13.3
# 2            3      HP           250 G6   Notebook    15.6
# 3            4   Apple      MacBook Pro  Ultrabook    15.4
# 4            5   Apple      MacBook Pro  Ultrabook    13.3
# ..         ...     ...              ...        ...     ...
# 539        546  Lenovo    Thinkpad E470   Notebook    14.0
# 540        547    Dell           XPS 13  Ultrabook    13.3
# 541        548    Dell      Vostro 5468   Notebook    14.0
# 542        549      HP  Envy 13-AB020nr  Ultrabook    13.3
# 543        550    Acer         Aspire 7     Gaming    15.6
#
#                        ScreenResolution                          Cpu   Ram  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 1                              1440x900         Intel Core i5 1.8GHz   8GB
# ...

# %%
df.head(10)
# Out:
#    laptop_ID Company          Product   TypeName  Inches  \
# 0          1   Apple      MacBook Pro  Ultrabook    13.3
# 1          2   Apple      Macbook Air  Ultrabook    13.3
# 2          3      HP           250 G6   Notebook    15.6
# 3          4   Apple      MacBook Pro  Ultrabook    15.4
# 4          5   Apple      MacBook Pro  Ultrabook    13.3
# 5          6    Acer         Aspire 3   Notebook    15.6
# 6          7   Apple      MacBook Pro  Ultrabook    15.4
# 7          8   Apple      Macbook Air  Ultrabook    13.3
# 8          9    Asus  ZenBook UX430UN  Ultrabook    14.0
# 9         10    Acer          Swift 3  Ultrabook    14.0
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# ...

# %%
#1)Count of each laptop according their brand in given dataset.

a["Company"].value_counts()       #value_counts function used to find laptop according to brand.
# Out:
# Company
# Dell         128
# Lenovo       118
# HP           102
# Asus          80
# Acer          52
# Apple         16
# MSI           15
# Toshiba       13
# Microsoft      5
# Chuwi          3
# Xiaomi         3
# Huawei         2
# Mediacom       2
# Google         2
# Vero           1
# Razer          1
# Samsung        1
# Name: count, dtype: int64

# %%
#2)Bar graph which represent Operating sys.
import matplotlib.pyplot as plt
s=a["OpSys"].value_counts()

plt.bar
# Out:
# OpSys
# Windows 10      447
# No OS            37
# Linux            29
# macOS            13
# Windows 10 S      7
# Chrome OS         6
# Mac OS X          3
# Android           1
# Windows 7         1
# Name: count, dtype: int64

# %%
#2)Bar graph which represent Operating sys.
import matplotlib.pyplot as plt
CountStatus = pd.value_counts(df['OpSys'].values, sort=True)
CountStatus.plot.bar()
# Out:
# C:\Users\Shraddha\AppData\Local\Temp\ipykernel_11684\485769535.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   CountStatus = pd.value_counts(df['OpSys'].values, sort=True)
# <Axes: >

# %%
#3)Remove the duplicates if it is.

# a.duplicated().value_counts()

#output :- False    394
# Name: count, dtype: int64  

a.drop_duplicates(inplace=True)
a
# Out:
# False    394
# Name: count, dtype: int64

# %%
#4)Add new columns as divide the columns according to their GB

a["Ram"].value_counts()    # to check Diff GB
# Out:
# Ram
# 8GB     200
# 4GB     100
# 16GB     58
# 12GB     12
# 6GB      10
# 2GB       7
# 32GB      4
# 24GB      3
# Name: count, dtype: int64

# %%
import pandas as pd
a=pd.read_csv("laptop_price .csv")

df=pd.DataFrame(a)

df["8GB"]=df["Ram"].apply(lambda x: "8GB" if x=="8GB" else "NA")
df["4GB"]=df["Ram"].apply(lambda x: "4GB" if x=="4GB" else "NA")
df["16GB"]=df["Ram"].apply(lambda x: "16GB" if x=="16GB" else "NA")
df["12GB"]=df["Ram"].apply(lambda x: "12GB" if x=="12GB" else "NA")
df["6GB"]=df["Ram"].apply(lambda x: "6GB" if x=="6GB" else "NA")
df["2GB"]=df["Ram"].apply(lambda x: "2GB" if x=="2GB" else "NA")
df["32GB"]=df["Ram"].apply(lambda x: "32GB" if x=="32GB" else "NA")
df["24GB"]=df["Ram"].apply(lambda x: "24GB" if x=="24GB" else "NA")

df
# Out:
#      laptop_ID Company          Product   TypeName  Inches  \
# 0            1   Apple      MacBook Pro  Ultrabook    13.3
# 1            2   Apple      Macbook Air  Ultrabook    13.3
# 2            3      HP           250 G6   Notebook    15.6
# 3            4   Apple      MacBook Pro  Ultrabook    15.4
# 4            5   Apple      MacBook Pro  Ultrabook    13.3
# ..         ...     ...              ...        ...     ...
# 539        546  Lenovo    Thinkpad E470   Notebook    14.0
# 540        547    Dell           XPS 13  Ultrabook    13.3
# 541        548    Dell      Vostro 5468   Notebook    14.0
# 542        549      HP  Envy 13-AB020nr  Ultrabook    13.3
# 543        550    Acer         Aspire 7     Gaming    15.6
#
#                        ScreenResolution                          Cpu   Ram  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 1                              1440x900         Intel Core i5 1.8GHz   8GB
# ...

# %%
# 5)which laptops has ScreenResolution as IPS Panel Retina Display 2880x1800

z=[]    #variable to save laptop
for i in range(len(df)):
    if df["ScreenResolution"][i] == "IPS Panel Retina Display 2880x1800":
        z.append(df["Product"][i])
print("laptops has ScreenResolution as IPS Panel Retina Display 2880x1800:",z)
# Out:
# laptops has ScreenResolution as IPS Panel Retina Display 2880x1800: ['MacBook Pro', 'MacBook Pro', 'MacBook Pro', 'MacBook Pro']

# %%
#6)Create Pie dig on Typename of Laptop 

a["TypeName"].value_counts()
import matplotlib.pyplot as plt
Status = pd.value_counts(df['TypeName'].values, sort=True)
Status.plot.pie()
# Out:
# C:\Users\Shraddha\AppData\Local\Temp\ipykernel_2352\3773925912.py:5: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   Status = pd.value_counts(df['TypeName'].values, sort=True)
# <Axes: ylabel='count'>

# %%
#7)Laptop names which weight between 1.5 to 2.5 kg


df['New_weight'] = df['Weight'].str.extract(r'(\d+.\d+)').astype(float)


x = df[(df['New_weight'] >= 1.5) & (df['New_weight'] <= 2.5)]

f = x['Product'].tolist()

f
# Out:
# ['250 G6',
#  'MacBook Pro',
#  'Aspire 3',
#  'MacBook Pro',
#  'Swift 3',
#  '250 G6',
#  '250 G6',
#  'MacBook Pro',
#  'Inspiron 3567',
#  'Inspiron 3567',
#  'MacBook Pro',
#  'IdeaPad 320-15IKB',
#  'Legion Y520-15IKBN',
#  '255 G6',
#  'Inspiron 5379',
#  '15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)',
#  'Inspiron 3567',
#  'Inspiron 5570',
#  'Latitude 5590',
#  'ProBook 470',
#  'LapBook 15.6"',
#  'E402WA-GA010T (E2-6110/2GB/32GB/W10)',
#  'Aspire 3',
#  '250 G6',
#  'ProBook 450',
#  'X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce',
#  'Aspire A515-51G',
#  'IdeaPad 320-15ISK',
#  'Inspiron 3567',
#  'Aspire A515-51G',
#  '255 G6',
#  'Aspire 3',
#  'Inspiron 3576',
#  '15-bs002nv (i3-6006U/4GB/128GB/FHD/W10)',
#  'GS73VR 7RG',
#  'Vostro 5471',
#  'IdeaPad 520S-14IKB',
#  '250 G6',
#  'ZenBook Pro',
#  '250 G6',
#  'V310-15ISK (i5-7200U/4GB/1TB/FHD/W10)',
#  'Inspiron 5570',
#  'Aspire E5-475',
#  'FX503VD-E4022T (i7-7700HQ/8GB/1TB/GeForce',
#  'IdeaPad 320-15IKBN',
# ...

# %%
# 8)Create new column convert currency euros to rupees
import pandas as pd
a=pd.read_csv("laptop_price .csv")

df=pd.DataFrame(a)
#1 Euro equals 89.31 Indian Rupee
df["Price_rupees"]=df["Price_euros"]*89.31
df
# Out:
#      laptop_ID Company          Product   TypeName  Inches  \
# 0            1   Apple      MacBook Pro  Ultrabook    13.3
# 1            2   Apple      Macbook Air  Ultrabook    13.3
# 2            3      HP           250 G6   Notebook    15.6
# 3            4   Apple      MacBook Pro  Ultrabook    15.4
# 4            5   Apple      MacBook Pro  Ultrabook    13.3
# ..         ...     ...              ...        ...     ...
# 539        546  Lenovo    Thinkpad E470   Notebook    14.0
# 540        547    Dell           XPS 13  Ultrabook    13.3
# 541        548    Dell      Vostro 5468   Notebook    14.0
# 542        549      HP  Envy 13-AB020nr  Ultrabook    13.3
# 543        550    Acer         Aspire 7     Gaming    15.6
#
#                        ScreenResolution                          Cpu   Ram  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 1                              1440x900         Intel Core i5 1.8GHz   8GB
# ...

# %%
#9)arrange the laptop according to their highest price to lowest


df=df.sort_values (by="Price_euros",ascending=False)
df
# Out:
#      laptop_ID Company                               Product     TypeName  \
# 196        200   Razer                             Blade Pro       Gaming
# 238        243    Asus                     ROG G703VI-E5062T       Gaming
# 204        208    Dell                        Precision 7520  Workstation
# 530        537    Dell                          Alienware 17       Gaming
# 247        252    Asus                    Rog G701VIK-BA060T       Gaming
# ..         ...     ...                                   ...          ...
# 30          31   Chuwi                         LapBook 15.6"     Notebook
# 67          69      HP                     Stream 14-AX040wm     Notebook
# 31          32    Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)     Notebook
# 290        295    Acer                  Chromebook C910-C2ST     Notebook
# 20          21    Asus                       Vivobook E200HA      Netbook
#
#      Inches                     ScreenResolution  \
# ...

# %%
#10)give the laptop name which contain 256GB SSD + 2TB HDD
import pandas as pd
a=pd.read_csv("C:\\Users\\Shraddha\\Desktop\\Python_Programs\\laptop_price .csv")

df=pd.DataFrame(a)

e = df[df['Memory'].str.contains('256GB SSD') & df['Memory'].str.contains('2TB HDD')]

# Get the laptop names
laptop_names = e['Product'].tolist()

print("Laptops containing both 256GB SSD and 2TB HDD:")
laptop_names
# Out:
# Laptops containing both 256GB SSD and 2TB HDD:
# ['GS73VR 7RG',
#  'Inspiron 5770',
#  'GS63VR 7RG',
#  'Inspiron 5770',
#  'Inspiron 5570',
#  'Legion Y520-15IKBN',
#  'Inspiron 5570',
#  'Inspiron 5570']

# %%
#11)create a pie dig according to laptop brands names.

a["Company"].value_counts()
import matplotlib.pyplot as plt
Status = pd.value_counts(df['Company'].values, sort=True)
Status.plot.pie()
# Out:
# C:\Users\Shraddha\AppData\Local\Temp\ipykernel_5076\1584864403.py:5: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   Status = pd.value_counts(df['Company'].values, sort=True)
# <Axes: ylabel='count'>

# %%
#12)Add new column which laptop belong to I3 intel generation.

df["New_generation"]=df["Cpu"]=="I3 intel"
df
# Out:
#      laptop_ID Company          Product   TypeName  Inches  \
# 0            1   Apple      MacBook Pro  Ultrabook    13.3
# 1            2   Apple      Macbook Air  Ultrabook    13.3
# 2            3      HP           250 G6   Notebook    15.6
# 3            4   Apple      MacBook Pro  Ultrabook    15.4
# 4            5   Apple      MacBook Pro  Ultrabook    13.3
# ..         ...     ...              ...        ...     ...
# 539        546  Lenovo    Thinkpad E470   Notebook    14.0
# 540        547    Dell           XPS 13  Ultrabook    13.3
# 541        548    Dell      Vostro 5468   Notebook    14.0
# 542        549      HP  Envy 13-AB020nr  Ultrabook    13.3
# 543        550    Acer         Aspire 7     Gaming    15.6
#
#                        ScreenResolution                          Cpu   Ram  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 1                              1440x900         Intel Core i5 1.8GHz   8GB
# ...

# %%
#13)which laptops has GPU is Nvidia GeForce GTX 1070
import pandas as pd
a=pd.read_csv("laptop_price .csv")

df=pd.DataFrame(a)

e = df[df['Gpu'].str.contains('Nvidia GeForce GTX 1070')]

# Get the laptop names
n = e['Product'].tolist()

print("laptops has GPU is Nvidia GeForce GTX 1070:")
n
# Out:
# laptops has GPU is Nvidia GeForce GTX 1070:
# ['GS73VR 7RG',
#  'GS63VR 7RG',
#  'GE72MVR 7RG',
#  'GT73EVR 7RE',
#  'Rog GL702VS-GC095T',
#  'GE63VR 7RF',
#  'GE73VR 7RF',
#  'Alienware 17',
#  'Omen 17-w207nv',
#  'Alienware 17']
